# %% [markdown]
# # Jupyter Notebook
# Projet L3 Laura Ciampi - encadré par L. Pecquerie

# %% [markdown]
# ### Afficher un message sur Python

# %%
print("Bonjour Jupyter")
# Out:
# Bonjour Jupyter

# %% [markdown]
# ### Ecrire une fonction renvoyant un message

# %%
def f():
    print("hello world")
f()
# Out:
# hello world
